# %%
import pandas
import numpy
data = pandas.read_excel('E:/JAN2016/KULIAH20182019/SEM1_20182019/KOMPUTASIMATEMATIKA/TUGAS_PROJECT/KANKER_jaringandenganYuni/CANCER1.xlsx')
print(data)
data.head()
# Out:
#            x1         x2         x3         x4         x5         x6  \
# 0   46.846584  43.864251  46.846584  44.371710  42.739942  15.000000
# 1   48.000000  44.926185  48.000000  45.449166  43.646138  15.323808
# 2   49.098411  45.936476  49.098411  46.474404  44.501786  15.629857
# 3   50.146900  46.899923  50.146900  47.452273  45.311825  15.919872
# 4   51.149840  47.820655  51.149840  48.386942  46.080493  16.195330
# 5   52.111026  48.702256  52.111026  49.282032  46.811457  16.457513
# 6   53.033776  49.547856  53.033776  50.140706  47.507911  16.707536
# 7   53.921012  50.360210  53.921012  50.965745  48.172655  16.946377
# 8   54.775317  51.141756  54.775317  51.759615  48.808163  17.174902
# 9   55.598995  51.894664  55.598995  52.524506  49.416626  17.393877
# 10  56.394103  52.620873  56.394103  53.262379  50.000000  17.603986
# 11  57.162492  53.322128  57.162492  53.974996  50.560036  17.805844
# 12  57.905830  54.000000  57.905830  54.663946  51.098308  18.000000
# ...

# %%
#Kasus multivariate regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from statsmodels.formula.api import ols

data = pandas.read_excel('E:/JAN2016/KULIAH20182019/SEM1_20182019/KOMPUTASIMATEMATIKA/TUGAS_PROJECT/KANKER_jaringandenganYuni/CANCER1.xlsx')
model = ols('target ~ x1+ x2 + x3 + x4 + x5 + x6 + x7 + x8', data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 8.537e+07
# Date:                Thu, 29 Nov 2018   Prob (F-statistic):           1.55e-69
# Time:                        23:21:07   Log-Likelihood:                 133.15
# No. Observations:                  26   AIC:                            -252.3
# Df Residuals:                      19   BIC:                            -243.5
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1862     73.634      0.003      0.998    -153.931     154.303
# ...
